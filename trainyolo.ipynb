# %%
#split data
import os
import shutil
from sklearn.model_selection import train_test_split

def split_data(images_dir, labels_dir, train_dir, val_dir, train_size=0.8):
    #splits data into training and validation sets

    # Ensure output directories exist
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(os.path.join(train_dir, 'images'), exist_ok=True)
    os.makedirs(os.path.join(train_dir, 'labels'), exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(os.path.join(val_dir, 'images'), exist_ok=True)
    os.makedirs(os.path.join(val_dir, 'labels'), exist_ok=True)

    # List all image files
    image_files = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

    # Split the dataset into training and validation sets
    train_files, val_files = train_test_split(image_files, train_size=train_size)

    # Function to copy files
    def copy_files(files, source_dir, target_dir):
        for f in files:
            # Copy image
            shutil.copy(os.path.join(source_dir, f), os.path.join(target_dir, 'images', f))
            # Copy corresponding label
            label_file = f.rsplit('.', 1)[0] + '.txt'
            shutil.copy(os.path.join(labels_dir, label_file), os.path.join(target_dir, 'labels', label_file))

    # Copy training files
    copy_files(train_files, images_dir, train_dir)
    # Copy validation files
    copy_files(val_files, images_dir, val_dir)

# Example usage
images_dir = 'images'  # Path to the directory containing images
labels_dir = 'labels'  # Path to the directory containing label files
train_dir = 'train'    # Path to the directory for training data
val_dir = 'val'        # Path to the directory for validation data

split_data(images_dir, labels_dir, train_dir, val_dir)

# %%
#create yaml
import yaml

def create_dataset_yaml(train_dir, val_dir, class_names, yaml_file_path):
    # Define the dataset structure
    dataset = {
        'train': train_dir,
        'val': val_dir,
        'nc': len(class_names),
        'names': class_names
    }

    # Write to a YAML file
    with open(yaml_file_path, 'w') as file:
        yaml.dump(dataset, file, sort_keys=False)

# Example usage
train_dir = '..\\train\\images'  
val_dir = '..\\val\\images'      
class_names = [str(i) for i in range(133)]  
yaml_file_path = 'dataset.yaml'     # Path where the YAML file will be saved

create_dataset_yaml(train_dir, val_dir, class_names, yaml_file_path)

# %%
# !python yolov5\\train.py --img 640 --batch 32 --epochs 1 --data dataset.yaml --cfg yolov5s.yaml --name yolov5s_results
# Out:
# ^C

# %%
# !python C:\\Users\\thesw\\yolov5\\detect.py --weights C:\Users\thesw\yolov5\runs\train\yolov5s_results22\weights\best.pt --img 640  --conf 0.25 --source C:\Users\thesw\Videos\vids\legends2.mp4 --save-txt --save-conf
# Out:
# detect: weights=['C:\\Users\\thesw\\yolov5\\runs\\train\\yolov5s_results22\\weights\\best.pt'], source=C:\Users\thesw\Videos\vids\legends2.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-241-gb6a65e1 Python-3.10.13 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7368826 parameters, 0 gradients, 16.9 GFLOPs
# video 1/1 (1/9013) C:\Users\thesw\Videos\vids\legends2.mp4: 384x640 1 86, 1 93, 1 107, 1 130, 88.6ms
# video 1/1 (2/9013) C:\Users\thesw\Videos\vids\legends2.mp4: 384x640 1 86, 1 93, 1 130, 8.0ms
# ...

# %%
# !python C:\\Users\\thesw\\yolov5\\detect.py --weights C:\Users\thesw\yolov5\runs\train\yolov5s_results22\weights\best.pt --img 640  --conf 0.25 --source C:\Users\thesw\Videos\vids\legends2.mp4 --save-txt --save-conf
# Out:
# detect: weights=['C:\\Users\\thesw\\yolov5\\runs\\train\\yolov5s_results22\\weights\\best.pt'], source=C:\Users\thesw\Videos\vids\legends2.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-241-gb6a65e1 Python-3.10.13 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7368826 parameters, 0 gradients, 16.9 GFLOPs
# video 1/1 (1/9013) C:\Users\thesw\Videos\vids\legends2.mp4: 384x640 1 86, 1 93, 1 107, 1 130, 99.8ms
# video 1/1 (2/9013) C:\Users\thesw\Videos\vids\legends2.mp4: 384x640 1 86, 1 93, 1 130, 8.4ms
# ...

# %%
import torch

def check_gpu():
    if torch.cuda.is_available():
        print("PyTorch is utilizing GPU!")
        print(f"GPU Device Name: {torch.cuda.get_device_name(0)}")
    else:
        print("PyTorch is not utilizing GPU.")

check_gpu()
# Out:
# PyTorch is utilizing GPU!
# GPU Device Name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB 5.6 MB/s eta 0:07:29
#      ---------------------------------------- 0.0/2.5 GB 28.7 MB/s eta 0:01:27
#      ---------------------------------------- 0.0/2.5 GB 33.6 MB/s eta 0:01:15
#      ---------------------------------------- 0.0/2.5 GB 33.1 MB/s eta 0:01:15
#      ---------------------------------------- 0.0/2.5 GB 32.7 MB/s eta 0:01:16
#       --------------------------------------- 0.0/2.5 GB 36.0 MB/s eta 0:01:09
#       --------------------------------------- 0.0/2.5 GB 33.2 MB/s eta 0:01:15
#       --------------------------------------- 0.1/2.5 GB 36.8 MB/s eta 0:01:07
#       --------------------------------------- 0.1/2.5 GB 35.7 MB/s eta 0:01:09
#      - -------------------------------------- 0.1/2.5 GB 36.4 MB/s eta 0:01:07
# ...

# %%
# !pip install yaml
# Out:
# ERROR: Could not find a version that satisfies the requirement yaml (from versions: none)
# ERROR: No matching distribution found for yaml

# %%
# !pip uninstall torch torchvision torchaudio
