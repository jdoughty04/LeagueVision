# %%
#maybe faster 
from PIL import Image
import os
import random

def create_augmented_data(map_dir, icons_dir, output_dir, labels_dir, num_images, max_icons, icon_width, icon_height, map_width, map_height):
    # Ensure output directories exist
    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(labels_dir, exist_ok=True)

    # Load and resize the map image
    map_image_path = os.path.join(map_dir, os.listdir(map_dir)[0])
    map_image = Image.open(map_image_path).resize((map_width, map_height), Image.Resampling.LANCZOS)
    map_image_base = map_image.copy()

    # Load, resize icons and create a mapping to unique keys
    icon_images = {}
    for icon_file in os.listdir(icons_dir):
        if os.path.isfile(os.path.join(icons_dir, icon_file)):
            with Image.open(os.path.join(icons_dir, icon_file)) as icon:
                icon_images[icon_file.rsplit('.', 1)[0]] = icon.resize((icon_width, icon_height), Image.Resampling.BILINEAR)
    icon_keys = {icon_name: i for i, icon_name in enumerate(icon_images)}

    # Print each icon's name along with its assigned key
    for icon_name, key in icon_keys.items():
        print(f"Icon: {icon_name}, Key: {key}")

    for i in range(num_images):
        map_image = map_image_base.copy()

        # File for storing labels
        label_file_path = os.path.join(labels_dir, f"img_{i}.txt")
        with open(label_file_path, 'w') as label_file:

            # Randomly select and place icons
            for _ in range(random.randint(1, max_icons)):
                icon_name = random.choice(list(icon_images.keys()))
                icon_key = icon_keys[icon_name]
                resized_icon = icon_images[icon_name]

                # Random position for the center of the icon
                center_x = random.randint(icon_width // 2, map_width - icon_width // 2)
                center_y = random.randint(icon_height // 2, map_height - icon_height // 2)

                # Top-left corner position
                x = center_x - icon_width // 2
                y = center_y - icon_height // 2

                # Normalize center coordinates
                normalized_x = center_x / map_width
                normalized_y = center_y / map_height

                # Overlay icon onto the map image
                map_image.paste(resized_icon, (x, y), resized_icon)

                # Write label with space-separated values, including the two additional zeroes
                label_file.write(f"{icon_key} {normalized_x:.2f} {normalized_y:.2f} 0.15 0.15\n")

        # Save the augmented image
        augmented_image_path = os.path.join(output_dir, f"img_{i}.png")
        map_image.save(augmented_image_path)

# Example usage
map_dir = 'map'
icons_dir = 'Icons'
output_dir = 'images'
labels_dir = 'labels'
num_images = 10000
max_icons = 5
icon_width = 266  # Desired width of the icons
icon_height = 150  # Desired height of the icons
map_width = 640  # Desired width of the map
map_height = 640  # Desired height of the map


create_augmented_data(map_dir, icons_dir, output_dir, labels_dir, num_images, max_icons, icon_width, icon_height, map_width, map_height)
# Out:
# Icon: Aatrox, Key: 0
# Icon: Ahri, Key: 1
# Icon: Akali, Key: 2
# Icon: Akshan, Key: 3
# Icon: Alistar, Key: 4
# Icon: Anivia, Key: 5
# Icon: Annie, Key: 6
# Icon: Aphelios, Key: 7
# Icon: Ashe, Key: 8
# Icon: Asol, Key: 9
# Icon: Bard, Key: 10
# Icon: Blitz, Key: 11
# Icon: Brand, Key: 12
# Icon: Braum, Key: 13
# Icon: Caitlyn, Key: 14
# Icon: Cassio, Key: 15
# Icon: cho, Key: 16
# Icon: Corki, Key: 17
# Icon: Darius, Key: 18
# Icon: Diana, Key: 19
# Icon: Draven, Key: 20
# Icon: Ekko, Key: 21
# Icon: Elise, Key: 22
# Icon: Evelyn, Key: 23
# Icon: Ezreal, Key: 24
# Icon: Fiora, Key: 25
# Icon: Fizz, Key: 26
# Icon: Galio, Key: 27
# Icon: Gangplank, Key: 28
# Icon: Garen, Key: 29
# Icon: Gragas, Key: 30
# Icon: Graves, Key: 31
# Icon: Gwen, Key: 32
# Icon: Hecarim, Key: 33
# Icon: Heimer, Key: 34
# Icon: Irelia, Key: 35
# Icon: Ivern, Key: 36
# Icon: Janna, Key: 37
# Icon: Jarvan, Key: 38
# Icon: JAx, Key: 39
# Icon: Jhin, Key: 40
# Icon: Jinx, Key: 41
# Icon: Kaisa, Key: 42
# Icon: Kalista, Key: 43
# Icon: Karma, Key: 44
# Icon: Kassadin, Key: 45
# Icon: Katarina, Key: 46
# Icon: Kayle, Key: 47
# Icon: Kayn, Key: 48
# Icon: Kennen, Key: 49
# Icon: Kindred, Key: 50
# Icon: Kled, Key: 51
# Icon: Kogmaw, Key: 52
# Icon: Leblanc, Key: 53
# Icon: Lee Sin, Key: 54
# Icon: Lillia, Key: 55
# Icon: Lissandra, Key: 56
# Icon: Lucian, Key: 57
# Icon: Lulu, Key: 58
# Icon: Lux, Key: 59
# Icon: Malzahar, Key: 60
# Icon: Maokai, Key: 61
# Icon: Master Yi, Key: 62
# Icon: Mega Gnar, Key: 63
# Icon: Miss Fortune, Key: 64
# Icon: Morgana, Key: 65
# Icon: Nami, Key: 66
# Icon: Nasus, Key: 67
# Icon: Nautilus, Key: 68
# Icon: Neeko, Key: 69
# Icon: Nocturne, Key: 70
# Icon: Nunu, Key: 71
# Icon: Olaf, Key: 72
# Icon: Orianna, Key: 73
# Icon: Ornn, Key: 74
# Icon: Poppy, Key: 75
# Icon: Pyke, Key: 76
# Icon: Qiyana, Key: 77
# Icon: Quinn, Key: 78
# Icon: Rakan, Key: 79
# Icon: RekSai, Key: 80
# Icon: Rell, Key: 81
# Icon: Renekton, Key: 82
# Icon: Rengar, Key: 83
# Icon: Riven, Key: 84
# Icon: Rumble, Key: 85
# Icon: Ryze, Key: 86
# Icon: Samira, Key: 87
# Icon: Sejuani, Key: 88
# Icon: Seraphine, Key: 89
# Icon: Sett, Key: 90
# Icon: Shaco, Key: 91
# Icon: Shadow Assassin, Key: 92
# Icon: Shen, Key: 93
# Icon: Singed, Key: 94
# Icon: Sion, Key: 95
# Icon: Sivir, Key: 96
# Icon: Skarner, Key: 97
# Icon: Sona, Key: 98
# Icon: Swain, Key: 99
# Icon: Sylas, Key: 100
# Icon: Syndra, Key: 101
# Icon: Tahm Kench, Key: 102
# Icon: Taliyah, Key: 103
# Icon: Taric, Key: 104
# Icon: Teemo, Key: 105
# Icon: Thresh, Key: 106
# Icon: Tristana, Key: 107
# Icon: Trundle, Key: 108
# Icon: Twisted Fate, Key: 109
# Icon: Twitch, Key: 110
# Icon: Udyr, Key: 111
# Icon: Urgot, Key: 112
# Icon: Varus, Key: 113
# Icon: Veigar, Key: 114
# Icon: VelKoz, Key: 115
# Icon: Vi, Key: 116
# Icon: Viego, Key: 117
# Icon: Viktor, Key: 118
# Icon: Volibear, Key: 119
# Icon: Warwick, Key: 120
# Icon: Wukong, Key: 121
# Icon: Xayah, Key: 122
# Icon: Xerath, Key: 123
# Icon: Yasuo, Key: 124
# Icon: Yone, Key: 125
# Icon: Yorick, Key: 126
# Icon: Yuumi, Key: 127
# Icon: Zac, Key: 128
# Icon: Ziggs, Key: 129
# Icon: Zilean, Key: 130
# Icon: Zoe, Key: 131
# Icon: Zyra, Key: 132

# %%
#check if pytorch is utilizing gpu

import torch

def check_gpu():
    if torch.cuda.is_available():
        print("PyTorch is utilizing GPU!")
        print(f"GPU Device Name: {torch.cuda.get_device_name(0)}")
    else:
        print("PyTorch is not utilizing GPU.")

check_gpu()
# Out:
# PyTorch is not utilizing GPU.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install pytorch torchvision torchaudio pytorch-cuda=12.4 -c pytorch -c nvidia
# Out:
# ^C
